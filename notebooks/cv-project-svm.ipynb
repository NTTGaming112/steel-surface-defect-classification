# %% [markdown]
# # SVM Classification - Steel Surface Defect Detection

# %%
import kagglehub

path = kagglehub.dataset_download("kaustubhdikshit/neu-surface-defect-database")
print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\ASUS\.cache\kagglehub\datasets\kaustubhdikshit\neu-surface-defect-database\versions\1

# %% [markdown]
# ## Import Libraries

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

from skimage.feature import local_binary_pattern
from sklearn.cluster import MiniBatchKMeans
from sklearn.preprocessing import StandardScaler

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

import optuna
from sklearn.model_selection import cross_val_score
import joblib
import json
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Configuration & Parameters

# %%
TRAIN_PATH="data/NEU-DET/train/images"
TEST_PATH = "data/NEU-DET/validation/images"
CHECKPOINT_DIR = "checkpoints"
MODEL_DIR = "models"

LBP_PARAMS = {
    "param1": {
        'radius': 1,
        'n_points': 8,
        'method': 'default'
    },
    'param2': {
        'radius': 1,
        'n_points': 8,
        'method': 'uniform'
    }
}

SIFT_PARAMS = {
    "param1": {
        'vocab_size': 100
    },
    'param2': {
        'vocab_size': 200
    }
}

class_names = sorted([f for f in os.listdir(TRAIN_PATH) if os.path.isdir(os.path.join(TRAIN_PATH, f))])

os.makedirs(CHECKPOINT_DIR, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)

# %% [markdown]
# ## Data Loading Functions

# %%
def load_data(dataset_path):
    """Load dataset and return DataFrame"""
    data = []
    class_names = sorted([f for f in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, f))])
        
    for label in class_names:
        class_path = os.path.join(dataset_path, label)
        image_files = [f for f in os.listdir(class_path) if f.endswith(('.jpg', '.png', '.bmp'))]
        
        for file_name in image_files:
            file_path = os.path.join(class_path, file_name)
            img = cv2.imread(file_path)
            data.append((file_path, label, img.shape))
            
    return pd.DataFrame(data, columns=['filepath', 'label', 'shape'])

# %%
df_train = load_data(TRAIN_PATH)
df_train.info()
df_train['label'].value_counts().sort_index()
df_train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filepath  1440 non-null   object
#  1   label     1440 non-null   object
#  2   shape     1440 non-null   object
# dtypes: object(3)
# memory usage: 33.9+ KB
#                                             filepath    label          shape
# 0    data/NEU-DET/train/images\crazing\crazing_1.jpg  crazing  (200, 200, 3)
# 1   data/NEU-DET/train/images\crazing\crazing_10.jpg  crazing  (200, 200, 3)
# 2  data/NEU-DET/train/images\crazing\crazing_100.jpg  crazing  (200, 200, 3)
# 3  data/NEU-DET/train/images\crazing\crazing_101.jpg  crazing  (200, 200, 3)
# 4  data/NEU-DET/train/images\crazing\crazing_102.jpg  crazing  (200, 200, 3)

# %%
df_test = load_data(TEST_PATH)
df_test.info()
df_test['label'].value_counts().sort_index()
df_test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filepath  360 non-null    object
#  1   label     360 non-null    object
#  2   shape     360 non-null    object
# dtypes: object(3)
# memory usage: 8.6+ KB
#                                             filepath    label          shape
# 0  data/NEU-DET/validation/images\crazing\crazing...  crazing  (200, 200, 3)
# 1  data/NEU-DET/validation/images\crazing\crazing...  crazing  (200, 200, 3)
# 2  data/NEU-DET/validation/images\crazing\crazing...  crazing  (200, 200, 3)
# 3  data/NEU-DET/validation/images\crazing\crazing...  crazing  (200, 200, 3)
# 4  data/NEU-DET/validation/images\crazing\crazing...  crazing  (200, 200, 3)

# %% [markdown]
# ## Image Preprocessing

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))

def preprocess_image(image):
    """Preprocess image: grayscale, resize, CLAHE"""
    image = cv2.imread(image)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.resize(gray, (200, 200), interpolation=cv2.INTER_AREA)
    gray = clahe.apply(gray)
    return gray

# %% [markdown]
# ## LBP Feature Extraction

# %%
def extract_lbp(image, radius=1, n_points=8, method='default'):
    """Extract LBP features with specified parameters"""
    gray = preprocess_image(image)
    lbp = local_binary_pattern(gray, n_points, radius, method=method)
    
    if method == 'uniform':
        n_bins = n_points + 3
    else:
        n_bins = 2 ** n_points
    
    hist, _ = np.histogram(lbp.ravel(), bins=n_bins, range=(0, n_bins))
    hist = hist.astype("float")
    hist /= (hist.sum() + 1e-6)
    
    return hist

# %% [markdown]
# ## SIFT BoW Feature Extraction

# %%
class SiftBowExtractor:
    """SIFT Bag-of-Words feature extractor"""
    def __init__(self, vocab_size=100):
        self.vocab_size = vocab_size
        self.kmeans = MiniBatchKMeans(n_clusters=self.vocab_size, 
                                      batch_size=200, 
                                      random_state=42,
                                      n_init=10)
        self.vocabulary = None

    def _get_sift_descriptors(self, image):
        sift = cv2.SIFT_create()
        gray = preprocess_image(image)
        _, descriptors = sift.detectAndCompute(gray, None)
        return descriptors

    def fit(self, image_paths):
        """Build vocabulary from training images"""
        all_descriptors = []
        
        for img_path in tqdm(image_paths, desc="Building SIFT vocabulary"):
            descriptors = self._get_sift_descriptors(img_path)
            if descriptors is not None:
                all_descriptors.append(descriptors)
            
        all_descriptors = np.vstack(all_descriptors)
        self.kmeans.fit(all_descriptors)
        self.vocabulary = self.kmeans.cluster_centers_

    def transform(self, image_paths):
        """Transform images to BoW histograms"""
        final_features = []
        
        for img_path in tqdm(image_paths, desc="Extracting SIFT features"):
            descriptors = self._get_sift_descriptors(img_path)
            hist = np.zeros(self.vocab_size, dtype=float)
            
            if descriptors is not None:
                visual_words = self.kmeans.predict(descriptors)
                hist, _ = np.histogram(visual_words, bins=np.arange(self.vocab_size + 1))
                hist = hist.astype(float)
                hist /= (hist.sum() + 1e-6)
            
            final_features.append(hist)
            
        return np.array(final_features)

# %% [markdown]
# ## Prepare Train/Test Data

# %%
X_train_paths = df_train['filepath'].tolist()
y_train = df_train['label'].tolist()

X_test_paths = df_test['filepath'].tolist()
y_test = df_test['label'].tolist()

# %% [markdown]
# ## Extract LBP Features

# %%
lbp_train = {}
lbp_test = {}

for param_name, params in LBP_PARAMS.items():
    X_train_lbp = np.array([extract_lbp(p, **params) for p in tqdm(X_train_paths, desc=f"LBP {param_name} train")])
    X_test_lbp = np.array([extract_lbp(p, **params) for p in tqdm(X_test_paths, desc=f"LBP {param_name} test")])
    
    lbp_train[param_name] = {'features': X_train_lbp, 'params': params}
    lbp_test[param_name] = {'features': X_test_lbp, 'params': params}
# Out:
# LBP param1 train: 100%|██████████| 1440/1440 [00:06<00:00, 230.56it/s]
# LBP param1 train: 100%|██████████| 1440/1440 [00:06<00:00, 230.56it/s]
# LBP param1 test: 100%|██████████| 360/360 [00:01<00:00, 232.59it/s]
# LBP param1 test: 100%|██████████| 360/360 [00:01<00:00, 232.59it/s]
# LBP param2 train: 100%|██████████| 1440/1440 [00:07<00:00, 189.64it/s]
# LBP param2 train: 100%|██████████| 1440/1440 [00:07<00:00, 189.64it/s]
# LBP param2 test: 100%|██████████| 360/360 [00:01<00:00, 183.37it/s]
# ✓ Extracted LBP features for 2 parameter sets

# %% [markdown]
# ## Extract SIFT Features

# %%
sift_train = {}
sift_test = {}

for param_name, params in SIFT_PARAMS.items():
    extractor = SiftBowExtractor(**params)
    
    print(f"\nProcessing SIFT {param_name}...")
    extractor.fit(X_train_paths)
    
    X_train_sift = extractor.transform(X_train_paths)
    X_test_sift = extractor.transform(X_test_paths)
    
    sift_train[param_name] = {'features': X_train_sift, 'params': params, 'extractor': extractor}
    sift_test[param_name] = {'features': X_test_sift, 'params': params}
    
    extractor_path = f"{MODEL_DIR}/sift_extractor_svm_{param_name}.pkl"
    joblib.dump(extractor, extractor_path)
# Out:
# Processing SIFT param1...
# Building SIFT vocabulary: 100%|██████████| 1440/1440 [00:12<00:00, 116.95it/s]
#
# Extracting SIFT features: 100%|██████████| 1440/1440 [00:18<00:00, 78.03it/s]
# Extracting SIFT features: 100%|██████████| 1440/1440 [00:18<00:00, 78.03it/s]
# Extracting SIFT features: 100%|██████████| 360/360 [00:04<00:00, 77.37it/s]
# Extracting SIFT features: 100%|██████████| 360/360 [00:04<00:00, 77.37it/s]
# Processing SIFT param2...
# Building SIFT vocabulary: 100%|██████████| 1440/1440 [00:12<00:00, 112.47it/s]
#
# Extracting SIFT features: 100%|██████████| 1440/1440 [00:16<00:00, 85.71it/s]
# Extracting SIFT features: 100%|██████████| 1440/1440 [00:16<00:00, 85.71it/s]
# Extracting SIFT features: 100%|██████████| 360/360 [00:04<00:00, 87.53it/s]
# ✓ Extracted SIFT features for 2 parameter sets

# %% [markdown]
# ## Feature Scaling

# %%
def scale_features(train_dict, test_dict):
    """Scale features for all parameter sets"""
    scaled = {}
    
    for param_name in train_dict.keys():
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(train_dict[param_name]['features'])
        X_test_scaled = scaler.transform(test_dict[param_name]['features'])
        
        scaled[param_name] = {
            'train': X_train_scaled,
            'test': X_test_scaled,
            'scaler': scaler
        }
    
    return scaled

lbp_scaled = scale_features(lbp_train, lbp_test)
sift_scaled = scale_features(sift_train, sift_test)

# %% [markdown]
# ## Optuna Optimization Setup

# %%
def objective_svm(trial, X_train, y_train):
    """Optuna objective function for SVM optimization"""
    kernel = trial.suggest_categorical('kernel', ['rbf', 'linear', 'poly'])
    C = trial.suggest_float('C', 0.1, 1000, log=True)
    
    if kernel == 'rbf':
        gamma = trial.suggest_categorical('gamma', ['scale', 'auto'])
        model = SVC(kernel=kernel, C=C, gamma=gamma, probability=True, random_state=42)
    elif kernel == 'poly':
        degree = trial.suggest_int('degree', 2, 5)
        gamma = trial.suggest_categorical('gamma', ['scale', 'auto'])
        model = SVC(kernel=kernel, C=C, gamma=gamma, degree=degree, probability=True, random_state=42)
    else:
        model = SVC(kernel=kernel, C=C, probability=True, random_state=42)
    
    cv_scores = cross_val_score(model, X_train, y_train, cv=3, scoring='accuracy', n_jobs=-1)
    return cv_scores.mean()

def build_feature_sets():
    """Build all feature sets for optimization"""
    feature_sets = {}
    
    for param_name in LBP_PARAMS.keys():
        feat_name = f"LBP_{param_name}"
        feature_sets[feat_name] = (
            lbp_scaled[param_name]['train'], 
            lbp_scaled[param_name]['test'], 
            lbp_train[param_name]['params']
        )
    
    for param_name in SIFT_PARAMS.keys():
        feat_name = f"SIFT_{param_name}"
        feature_sets[feat_name] = (
            sift_scaled[param_name]['train'], 
            sift_scaled[param_name]['test'], 
            sift_train[param_name]['params']
        )
    
    return feature_sets

feature_sets = build_feature_sets()

# %% [markdown]
# ## Train & Save Models

# %%
def train_and_save_model(feat_name, X_train, X_test, y_train, y_test, feat_params):
    """Train model with Optuna and save artifacts"""
    print(f"\n🔄 {feat_name} | Shape: {X_train.shape}")
    
    study = optuna.create_study(
        direction='maximize',
        study_name=f'SVM_{feat_name}',
        sampler=optuna.samplers.TPESampler(seed=42)
    )
    
    study.optimize(
        lambda trial: objective_svm(trial, X_train, y_train),
        n_trials=100,
        show_progress_bar=True
    )
    
    best_model = SVC(**study.best_params, probability=True, random_state=42)
    best_model.fit(X_train, y_train)
    
    y_pred = best_model.predict(X_test)
    test_accuracy = accuracy_score(y_test, y_pred)
    
    print(f"✓ {feat_name}: CV={study.best_value:.4f} | Test={test_accuracy:.4f}")
    
    joblib.dump(study, f"{CHECKPOINT_DIR}/study_svm_{feat_name}.pkl")
    joblib.dump(best_model, f"{MODEL_DIR}/best_svm_{feat_name}.pkl")
    
    if feat_name.startswith("LBP"):
        param_name = feat_name.replace("LBP_", "")
        scaler = lbp_scaled[param_name]['scaler']
    else:
        param_name = feat_name.replace("SIFT_", "")
        scaler = sift_scaled[param_name]['scaler']
    
    joblib.dump(scaler, f"{MODEL_DIR}/scaler_svm_{feat_name}.pkl")
    
    metadata = {
        'feature_set': feat_name,
        'feature_params': feat_params,
        'model_type': 'SVM',
        'best_params': study.best_params,
        'cv_accuracy': float(study.best_value),
        'test_accuracy': float(test_accuracy),
        'n_trials': len(study.trials),
        'train_shape': X_train.shape,
        'timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    }
    
    with open(f"{MODEL_DIR}/metadata_svm_{feat_name}.json", 'w') as f:
        json.dump(metadata, f, indent=2)
    
    return {
        'study': study,
        'model': best_model,
        'cv_accuracy': study.best_value,
        'test_accuracy': test_accuracy,
        'best_params': study.best_params,
        'feature_params': feat_params
    }

optuna_results = {}
for feat_name, (X_train, X_test, feat_params) in feature_sets.items():
    optuna_results[feat_name] = train_and_save_model(
        feat_name, X_train, X_test, y_train, y_test, feat_params
    )
# Out:
# [I 2025-11-22 01:35:10,945] A new study created in memory with name: SVM_LBP_param1
# 🔄 LBP_param1 | Shape: (1440, 256)
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-11-22 01:35:14,334] Trial 0 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 24.81040974867808}. Best is trial 0 with value: 0.8979166666666667.
# [I 2025-11-22 01:35:17,176] Trial 1 finished with value: 0.9055555555555556 and parameters: {'kernel': 'rbf', 'C': 291.5443189153751, 'gamma': 'auto'}. Best is trial 1 with value: 0.9055555555555556.
# [I 2025-11-22 01:35:17,176] Trial 1 finished with value: 0.9055555555555556 and parameters: {'kernel': 'rbf', 'C': 291.5443189153751, 'gamma': 'auto'}. Best is trial 1 with value: 0.9055555555555556.
# [I 2025-11-22 01:35:19,853] Trial 2 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 0.70689749506246}. Best is trial 1 with value: 0.9055555555555556.
# [I 2025-11-22 01:35:19,853] Trial 2 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 0.70689749506246}. Best is trial 1 with value: 0.9055555555555556.
# [I 2025-11-22 01:35:22,562] Trial 3 finished with value: 0.8923611111111112 and parameters: {'kernel': 'poly', 'C': 12.561043700013547, 'degree': 3, 'gamma': 'auto'}. Best is trial 1 with value: 0.9055555555555556.
# [I 2025-11-22 01:35:22,562] Trial 3 finished with value: 0.8923611111111112 and parameters: {'kernel': 'poly', 'C': 12.561043700013547, 'degree': 3, 'gamma': 'auto'}. Best is trial 1 with value: 0.9055555555555556.
# [I 2025-11-22 01:35:25,263] Trial 4 finished with value: 0.845138888888889 and parameters: {'kernel': 'poly', 'C': 6.6723671704642005, 'degree': 5, 'gamma': 'auto'}. Best is trial 1 with value: 0.9055555555555556.
# [I 2025-11-22 01:35:25,263] Trial 4 finished with value: 0.845138888888889 and parameters: {'kernel': 'poly', 'C': 6.6723671704642005, 'degree': 5, 'gamma': 'auto'}. Best is trial 1 with value: 0.9055555555555556.
# [I 2025-11-22 01:35:27,436] Trial 5 finished with value: 0.8555555555555555 and parameters: {'kernel': 'poly', 'C': 0.4809461967501573, 'degree': 2, 'gamma': 'auto'}. Best is trial 1 with value: 0.9055555555555556.
# [I 2025-11-22 01:35:27,436] Trial 5 finished with value: 0.8555555555555555 and parameters: {'kernel': 'poly', 'C': 0.4809461967501573, 'degree': 2, 'gamma': 'auto'}. Best is trial 1 with value: 0.9055555555555556.
# [I 2025-11-22 01:35:27,806] Trial 6 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 54.56725485601472, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:27,806] Trial 6 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 54.56725485601472, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:28,134] Trial 7 finished with value: 0.8076388888888889 and parameters: {'kernel': 'poly', 'C': 1.0842262717330158, 'degree': 4, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:28,134] Trial 7 finished with value: 0.8076388888888889 and parameters: {'kernel': 'poly', 'C': 1.0842262717330158, 'degree': 4, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:28,419] Trial 8 finished with value: 0.8569444444444444 and parameters: {'kernel': 'poly', 'C': 126.04664585649451, 'degree': 5, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:28,419] Trial 8 finished with value: 0.8569444444444444 and parameters: {'kernel': 'poly', 'C': 126.04664585649451, 'degree': 5, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:28,859] Trial 9 finished with value: 0.8458333333333333 and parameters: {'kernel': 'rbf', 'C': 0.151673306880762, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:28,859] Trial 9 finished with value: 0.8458333333333333 and parameters: {'kernel': 'rbf', 'C': 0.151673306880762, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:29,200] Trial 10 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 66.76281004302606, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:29,200] Trial 10 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 66.76281004302606, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:29,551] Trial 11 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 72.55685482622853, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:29,551] Trial 11 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 72.55685482622853, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:29,880] Trial 12 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 670.5764677935547, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:29,880] Trial 12 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 670.5764677935547, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:30,250] Trial 13 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 40.42336826324917, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:30,250] Trial 13 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 40.42336826324917, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:30,654] Trial 14 finished with value: 0.9034722222222222 and parameters: {'kernel': 'rbf', 'C': 4.521224720229949, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:30,654] Trial 14 finished with value: 0.9034722222222222 and parameters: {'kernel': 'rbf', 'C': 4.521224720229949, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:30,993] Trial 15 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 160.8881187785972, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:30,993] Trial 15 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 160.8881187785972, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:31,355] Trial 16 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 482.717137053172, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:31,557] Trial 17 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 2.661529236034324}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:31,355] Trial 16 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 482.717137053172, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:31,557] Trial 17 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 2.661529236034324}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:31,924] Trial 18 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 17.67149599858808, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:31,924] Trial 18 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 17.67149599858808, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:32,272] Trial 19 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 49.59713565737136, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:32,475] Trial 20 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 994.1450502972599}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:32,272] Trial 19 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 49.59713565737136, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:32,475] Trial 20 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 994.1450502972599}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:32,847] Trial 21 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 76.40529357150196, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:32,847] Trial 21 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 76.40529357150196, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:33,195] Trial 22 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 212.91081992967008, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:33,195] Trial 22 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 212.91081992967008, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:33,537] Trial 23 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 58.21203253969327, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:33,537] Trial 23 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 58.21203253969327, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:33,876] Trial 24 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 101.49711533225454, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:33,876] Trial 24 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 101.49711533225454, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:34,216] Trial 25 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 29.022881410782635, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:34,216] Trial 25 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 29.022881410782635, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:34,565] Trial 26 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 11.230665175520356, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:34,565] Trial 26 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 11.230665175520356, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:34,925] Trial 27 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 364.27632008351753, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:35,125] Trial 28 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 88.67948509073507}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:34,925] Trial 27 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 364.27632008351753, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:35,125] Trial 28 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 88.67948509073507}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:35,465] Trial 29 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 24.53306911823179, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:35,465] Trial 29 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 24.53306911823179, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:35,678] Trial 30 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 32.197079851512314}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:35,678] Trial 30 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 32.197079851512314}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:36,017] Trial 31 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 866.4402392334525, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:36,017] Trial 31 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 866.4402392334525, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:36,355] Trial 32 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 545.3741005517043, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:36,355] Trial 32 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 545.3741005517043, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:36,705] Trial 33 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 231.40154290742646, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:36,705] Trial 33 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 231.40154290742646, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:37,044] Trial 34 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 151.16640554924103, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:37,044] Trial 34 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 151.16640554924103, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:37,373] Trial 35 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 313.99816944623683, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:37,373] Trial 35 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 313.99816944623683, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:37,649] Trial 36 finished with value: 0.8951388888888889 and parameters: {'kernel': 'poly', 'C': 6.917430994658689, 'degree': 2, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:37,649] Trial 36 finished with value: 0.8951388888888889 and parameters: {'kernel': 'poly', 'C': 6.917430994658689, 'degree': 2, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:38,018] Trial 37 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 18.352580995024493, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:38,018] Trial 37 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 18.352580995024493, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:38,317] Trial 38 finished with value: 0.8527777777777779 and parameters: {'kernel': 'poly', 'C': 60.9846364235152, 'degree': 4, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:38,518] Trial 39 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 2.1297755576581445}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:38,317] Trial 38 finished with value: 0.8527777777777779 and parameters: {'kernel': 'poly', 'C': 60.9846364235152, 'degree': 4, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:38,518] Trial 39 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 2.1297755576581445}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:38,868] Trial 40 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 556.0118171827004, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:38,868] Trial 40 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 556.0118171827004, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:39,197] Trial 41 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 37.373954528331495, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:39,197] Trial 41 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 37.373954528331495, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:39,536] Trial 42 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 41.93964916165169, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:39,536] Trial 42 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 41.93964916165169, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:39,886] Trial 43 finished with value: 0.9055555555555556 and parameters: {'kernel': 'rbf', 'C': 124.63887936658121, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:39,886] Trial 43 finished with value: 0.9055555555555556 and parameters: {'kernel': 'rbf', 'C': 124.63887936658121, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:40,212] Trial 44 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 18.456586293073013, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:40,212] Trial 44 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 18.456586293073013, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:40,532] Trial 45 finished with value: 0.7229166666666668 and parameters: {'kernel': 'poly', 'C': 0.13537172298275307, 'degree': 3, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:40,532] Trial 45 finished with value: 0.7229166666666668 and parameters: {'kernel': 'poly', 'C': 0.13537172298275307, 'degree': 3, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:40,912] Trial 46 finished with value: 0.9048611111111112 and parameters: {'kernel': 'rbf', 'C': 7.572849695261556, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:40,912] Trial 46 finished with value: 0.9048611111111112 and parameters: {'kernel': 'rbf', 'C': 7.572849695261556, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:41,275] Trial 47 finished with value: 0.9034722222222222 and parameters: {'kernel': 'rbf', 'C': 4.302504290116594, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:41,275] Trial 47 finished with value: 0.9034722222222222 and parameters: {'kernel': 'rbf', 'C': 4.302504290116594, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:41,635] Trial 48 finished with value: 0.9055555555555556 and parameters: {'kernel': 'rbf', 'C': 194.96379290825416, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:41,635] Trial 48 finished with value: 0.9055555555555556 and parameters: {'kernel': 'rbf', 'C': 194.96379290825416, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:41,976] Trial 49 finished with value: 0.6104166666666667 and parameters: {'kernel': 'poly', 'C': 0.33781047216779797, 'degree': 5, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:41,976] Trial 49 finished with value: 0.6104166666666667 and parameters: {'kernel': 'poly', 'C': 0.33781047216779797, 'degree': 5, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:42,325] Trial 50 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 81.1129751818597, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:42,325] Trial 50 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 81.1129751818597, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:42,664] Trial 51 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 148.86487395331108, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:42,664] Trial 51 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 148.86487395331108, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:42,993] Trial 52 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 56.65550218264531, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:42,993] Trial 52 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 56.65550218264531, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:43,356] Trial 53 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 110.75981380086219, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:43,356] Trial 53 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 110.75981380086219, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:43,693] Trial 54 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 412.02576202702596, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:43,693] Trial 54 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 412.02576202702596, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:44,020] Trial 55 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 255.2023561389397, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:44,020] Trial 55 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 255.2023561389397, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:44,234] Trial 56 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 177.925553431042}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:44,234] Trial 56 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 177.925553431042}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:44,584] Trial 57 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 757.1632934168223, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:44,584] Trial 57 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 757.1632934168223, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:44,924] Trial 58 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 25.096163701538266, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:44,924] Trial 58 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 25.096163701538266, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:45,252] Trial 59 finished with value: 0.9055555555555556 and parameters: {'kernel': 'rbf', 'C': 77.35296961565808, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:45,252] Trial 59 finished with value: 0.9055555555555556 and parameters: {'kernel': 'rbf', 'C': 77.35296961565808, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:45,593] Trial 60 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 14.466970791634512, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:45,593] Trial 60 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 14.466970791634512, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:45,930] Trial 61 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 448.16538848044326, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:45,930] Trial 61 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 448.16538848044326, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:46,302] Trial 62 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 738.1057029286616, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:46,302] Trial 62 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 738.1057029286616, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:46,954] Trial 63 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 299.8425165764528, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:46,954] Trial 63 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 299.8425165764528, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:47,468] Trial 64 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 42.90506360990337, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:47,468] Trial 64 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 42.90506360990337, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:47,717] Trial 65 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 62.570526782211985}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:47,717] Trial 65 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 62.570526782211985}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:48,156] Trial 66 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 579.1140852478308, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:48,156] Trial 66 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 579.1140852478308, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:48,602] Trial 67 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 100.78490596585291, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:48,602] Trial 67 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 100.78490596585291, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:48,961] Trial 68 finished with value: 0.8923611111111112 and parameters: {'kernel': 'poly', 'C': 153.16315587071153, 'degree': 3, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:48,961] Trial 68 finished with value: 0.8923611111111112 and parameters: {'kernel': 'poly', 'C': 153.16315587071153, 'degree': 3, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:49,452] Trial 69 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 244.02564657035228, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:49,452] Trial 69 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 244.02564657035228, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:49,995] Trial 70 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 30.354285212972222, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:49,995] Trial 70 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 30.354285212972222, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:50,512] Trial 71 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 19.09021992543725, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:50,512] Trial 71 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 19.09021992543725, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:50,933] Trial 72 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 47.865366976134354, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:50,933] Trial 72 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 47.865366976134354, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:51,403] Trial 73 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 8.903531109635043, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:51,403] Trial 73 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 8.903531109635043, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:51,827] Trial 74 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 14.072928560710322, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:51,827] Trial 74 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 14.072928560710322, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:52,284] Trial 75 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 960.5398854534504, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:52,284] Trial 75 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 960.5398854534504, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:52,520] Trial 76 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 72.87036917907628}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:52,520] Trial 76 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 72.87036917907628}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:52,954] Trial 77 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 37.587652566139944, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:52,954] Trial 77 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 37.587652566139944, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:53,374] Trial 78 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 23.18867805288672, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:53,374] Trial 78 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 23.18867805288672, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:53,832] Trial 79 finished with value: 0.9055555555555556 and parameters: {'kernel': 'rbf', 'C': 346.3111808375914, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:53,832] Trial 79 finished with value: 0.9055555555555556 and parameters: {'kernel': 'rbf', 'C': 346.3111808375914, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:54,207] Trial 80 finished with value: 0.84375 and parameters: {'kernel': 'poly', 'C': 5.195167498787631, 'degree': 4, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:54,207] Trial 80 finished with value: 0.84375 and parameters: {'kernel': 'poly', 'C': 5.195167498787631, 'degree': 4, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:54,633] Trial 81 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 51.95140193020946, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:54,633] Trial 81 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 51.95140193020946, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:55,057] Trial 82 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 31.49623675497379, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:55,057] Trial 82 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 31.49623675497379, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:55,504] Trial 83 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 87.60898080063785, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:55,504] Trial 83 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 87.60898080063785, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:55,974] Trial 84 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 109.77496936381873, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:55,974] Trial 84 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 109.77496936381873, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:56,373] Trial 85 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 132.56850849944516, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:56,373] Trial 85 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 132.56850849944516, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:56,789] Trial 86 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 64.92246874128945, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:56,789] Trial 86 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 64.92246874128945, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:57,247] Trial 87 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 22.723961352758707, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:57,247] Trial 87 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 22.723961352758707, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:57,673] Trial 88 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 37.81381200933971, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:57,673] Trial 88 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 37.81381200933971, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:58,129] Trial 89 finished with value: 0.9055555555555556 and parameters: {'kernel': 'rbf', 'C': 190.6430742342329, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:58,129] Trial 89 finished with value: 0.9055555555555556 and parameters: {'kernel': 'rbf', 'C': 190.6430742342329, 'gamma': 'auto'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:58,359] Trial 90 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 481.5658998041436}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:58,359] Trial 90 finished with value: 0.8979166666666667 and parameters: {'kernel': 'linear', 'C': 481.5658998041436}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:58,801] Trial 91 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 48.248176621665266, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:58,801] Trial 91 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 48.248176621665266, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:59,261] Trial 92 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 73.6446044323197, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:59,261] Trial 92 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 73.6446044323197, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:59,675] Trial 93 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 55.728735117336676, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:35:59,675] Trial 93 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 55.728735117336676, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:36:00,102] Trial 94 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 96.3991561910925, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:36:00,102] Trial 94 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 96.3991561910925, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:36:00,564] Trial 95 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 12.115985638324474, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:36:00,564] Trial 95 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 12.115985638324474, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:36:00,890] Trial 96 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 619.1791139004754, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:36:00,890] Trial 96 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 619.1791139004754, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:36:01,237] Trial 97 finished with value: 0.8958333333333334 and parameters: {'kernel': 'poly', 'C': 130.4135044847418, 'degree': 2, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:36:01,237] Trial 97 finished with value: 0.8958333333333334 and parameters: {'kernel': 'poly', 'C': 130.4135044847418, 'degree': 2, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:36:01,693] Trial 98 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 26.44404153993667, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:36:01,693] Trial 98 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 26.44404153993667, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:36:02,126] Trial 99 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 173.01050658187577, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:36:02,126] Trial 99 finished with value: 0.90625 and parameters: {'kernel': 'rbf', 'C': 173.01050658187577, 'gamma': 'scale'}. Best is trial 6 with value: 0.90625.
# [I 2025-11-22 01:36:02,513] A new study created in memory with name: SVM_LBP_param2
# ✓ LBP_param1: CV=0.9062 | Test=0.9111
#
# 🔄 LBP_param2 | Shape: (1440, 11)
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-11-22 01:36:02,671] Trial 0 finished with value: 0.8548611111111111 and parameters: {'kernel': 'linear', 'C': 24.81040974867808}. Best is trial 0 with value: 0.8548611111111111.
# [I 2025-11-22 01:36:02,804] Trial 1 finished with value: 0.8576388888888888 and parameters: {'kernel': 'rbf', 'C': 291.5443189153751, 'gamma': 'auto'}. Best is trial 1 with value: 0.8576388888888888.
# [I 2025-11-22 01:36:02,877] Trial 2 finished with value: 0.8513888888888889 and parameters: {'kernel': 'linear', 'C': 0.70689749506246}. Best is trial 1 with value: 0.8576388888888888.
# [I 2025-11-22 01:36:02,804] Trial 1 finished with value: 0.8576388888888888 and parameters: {'kernel': 'rbf', 'C': 291.5443189153751, 'gamma': 'auto'}. Best is trial 1 with value: 0.8576388888888888.
# [I 2025-11-22 01:36:02,877] Trial 2 finished with value: 0.8513888888888889 and parameters: {'kernel': 'linear', 'C': 0.70689749506246}. Best is trial 1 with value: 0.8576388888888888.
# [I 2025-11-22 01:36:02,957] Trial 3 finished with value: 0.8194444444444443 and parameters: {'kernel': 'poly', 'C': 12.561043700013547, 'degree': 3, 'gamma': 'auto'}. Best is trial 1 with value: 0.8576388888888888.
# [I 2025-11-22 01:36:02,957] Trial 3 finished with value: 0.8194444444444443 and parameters: {'kernel': 'poly', 'C': 12.561043700013547, 'degree': 3, 'gamma': 'auto'}. Best is trial 1 with value: 0.8576388888888888.
# [I 2025-11-22 01:36:03,060] Trial 4 finished with value: 0.725 and parameters: {'kernel': 'poly', 'C': 6.6723671704642005, 'degree': 5, 'gamma': 'auto'}. Best is trial 1 with value: 0.8576388888888888.
# [I 2025-11-22 01:36:03,060] Trial 4 finished with value: 0.725 and parameters: {'kernel': 'poly', 'C': 6.6723671704642005, 'degree': 5, 'gamma': 'auto'}. Best is trial 1 with value: 0.8576388888888888.
# [I 2025-11-22 01:36:03,204] Trial 5 finished with value: 0.7000000000000001 and parameters: {'kernel': 'poly', 'C': 0.4809461967501573, 'degree': 2, 'gamma': 'auto'}. Best is trial 1 with value: 0.8576388888888888.
# [I 2025-11-22 01:36:03,204] Trial 5 finished with value: 0.7000000000000001 and parameters: {'kernel': 'poly', 'C': 0.4809461967501573, 'degree': 2, 'gamma': 'auto'}. Best is trial 1 with value: 0.8576388888888888.
# [I 2025-11-22 01:36:03,297] Trial 6 finished with value: 0.8659722222222221 and parameters: {'kernel': 'rbf', 'C': 54.56725485601472, 'gamma': 'scale'}. Best is trial 6 with value: 0.8659722222222221.
# [I 2025-11-22 01:36:03,297] Trial 6 finished with value: 0.8659722222222221 and parameters: {'kernel': 'rbf', 'C': 54.56725485601472, 'gamma': 'scale'}. Best is trial 6 with value: 0.8659722222222221.
# [I 2025-11-22 01:36:03,450] Trial 7 finished with value: 0.6631944444444445 and parameters: {'kernel': 'poly', 'C': 1.0842262717330158, 'degree': 4, 'gamma': 'auto'}. Best is trial 6 with value: 0.8659722222222221.
# [I 2025-11-22 01:36:03,450] Trial 7 finished with value: 0.6631944444444445 and parameters: {'kernel': 'poly', 'C': 1.0842262717330158, 'degree': 4, 'gamma': 'auto'}. Best is trial 6 with value: 0.8659722222222221.
# [I 2025-11-22 01:36:03,566] Trial 8 finished with value: 0.8020833333333334 and parameters: {'kernel': 'poly', 'C': 126.04664585649451, 'degree': 5, 'gamma': 'scale'}. Best is trial 6 with value: 0.8659722222222221.
# [I 2025-11-22 01:36:03,566] Trial 8 finished with value: 0.8020833333333334 and parameters: {'kernel': 'poly', 'C': 126.04664585649451, 'degree': 5, 'gamma': 'scale'}. Best is trial 6 with value: 0.8659722222222221.
# [I 2025-11-22 01:36:03,753] Trial 9 finished with value: 0.7854166666666668 and parameters: {'kernel': 'rbf', 'C': 0.151673306880762, 'gamma': 'auto'}. Best is trial 6 with value: 0.8659722222222221.
# [I 2025-11-22 01:36:03,753] Trial 9 finished with value: 0.7854166666666668 and parameters: {'kernel': 'rbf', 'C': 0.151673306880762, 'gamma': 'auto'}. Best is trial 6 with value: 0.8659722222222221.
# [I 2025-11-22 01:36:03,849] Trial 10 finished with value: 0.8638888888888889 and parameters: {'kernel': 'rbf', 'C': 66.76281004302606, 'gamma': 'scale'}. Best is trial 6 with value: 0.8659722222222221.
# [I 2025-11-22 01:36:03,949] Trial 11 finished with value: 0.8652777777777777 and parameters: {'kernel': 'rbf', 'C': 72.55685482622853, 'gamma': 'scale'}. Best is trial 6 with value: 0.8659722222222221.
# [I 2025-11-22 01:36:03,849] Trial 10 finished with value: 0.8638888888888889 and parameters: {'kernel': 'rbf', 'C': 66.76281004302606, 'gamma': 'scale'}. Best is trial 6 with value: 0.8659722222222221.
# [I 2025-11-22 01:36:03,949] Trial 11 finished with value: 0.8652777777777777 and parameters: {'kernel': 'rbf', 'C': 72.55685482622853, 'gamma': 'scale'}. Best is trial 6 with value: 0.8659722222222221.
# [I 2025-11-22 01:36:04,067] Trial 12 finished with value: 0.8576388888888888 and parameters: {'kernel': 'rbf', 'C': 670.5764677935547, 'gamma': 'scale'}. Best is trial 6 with value: 0.8659722222222221.
# [I 2025-11-22 01:36:04,159] Trial 13 finished with value: 0.8694444444444445 and parameters: {'kernel': 'rbf', 'C': 43.00727234782029, 'gamma': 'scale'}. Best is trial 13 with value: 0.8694444444444445.
# [I 2025-11-22 01:36:04,250] Trial 14 finished with value: 0.8548611111111111 and parameters: {'kernel': 'rbf', 'C': 4.43775512044645, 'gamma': 'scale'}. Best is trial 13 with value: 0.8694444444444445.
# [I 2025-11-22 01:36:04,067] Trial 12 finished with value: 0.8576388888888888 and parameters: {'kernel': 'rbf', 'C': 670.5764677935547, 'gamma': 'scale'}. Best is trial 6 with value: 0.8659722222222221.
# [I 2025-11-22 01:36:04,159] Trial 13 finished with value: 0.8694444444444445 and parameters: {'kernel': 'rbf', 'C': 43.00727234782029, 'gamma': 'scale'}. Best is trial 13 with value: 0.8694444444444445.
# [I 2025-11-22 01:36:04,250] Trial 14 finished with value: 0.8548611111111111 and parameters: {'kernel': 'rbf', 'C': 4.43775512044645, 'gamma': 'scale'}. Best is trial 13 with value: 0.8694444444444445.
# [I 2025-11-22 01:36:04,346] Trial 15 finished with value: 0.8722222222222222 and parameters: {'kernel': 'rbf', 'C': 26.83719341440015, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:04,451] Trial 16 finished with value: 0.8562500000000001 and parameters: {'kernel': 'rbf', 'C': 3.0215675878415604, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:04,346] Trial 15 finished with value: 0.8722222222222222 and parameters: {'kernel': 'rbf', 'C': 26.83719341440015, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:04,451] Trial 16 finished with value: 0.8562500000000001 and parameters: {'kernel': 'rbf', 'C': 3.0215675878415604, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:04,596] Trial 17 finished with value: 0.8541666666666666 and parameters: {'kernel': 'linear', 'C': 27.308349581482755}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:04,711] Trial 18 finished with value: 0.8576388888888888 and parameters: {'kernel': 'rbf', 'C': 287.17043296641475, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:04,596] Trial 17 finished with value: 0.8541666666666666 and parameters: {'kernel': 'linear', 'C': 27.308349581482755}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:04,711] Trial 18 finished with value: 0.8576388888888888 and parameters: {'kernel': 'rbf', 'C': 287.17043296641475, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:04,814] Trial 19 finished with value: 0.8715277777777778 and parameters: {'kernel': 'rbf', 'C': 16.317854542245655, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:04,919] Trial 20 finished with value: 0.8569444444444444 and parameters: {'kernel': 'linear', 'C': 13.101727892010578}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:04,814] Trial 19 finished with value: 0.8715277777777778 and parameters: {'kernel': 'rbf', 'C': 16.317854542245655, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:04,919] Trial 20 finished with value: 0.8569444444444444 and parameters: {'kernel': 'linear', 'C': 13.101727892010578}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:05,022] Trial 21 finished with value: 0.8715277777777778 and parameters: {'kernel': 'rbf', 'C': 27.679051104468822, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:05,150] Trial 22 finished with value: 0.8534722222222223 and parameters: {'kernel': 'rbf', 'C': 2.5969237576905977, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:05,022] Trial 21 finished with value: 0.8715277777777778 and parameters: {'kernel': 'rbf', 'C': 27.679051104468822, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:05,150] Trial 22 finished with value: 0.8534722222222223 and parameters: {'kernel': 'rbf', 'C': 2.5969237576905977, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:05,243] Trial 23 finished with value: 0.8722222222222222 and parameters: {'kernel': 'rbf', 'C': 21.887333318066418, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:05,335] Trial 24 finished with value: 0.86875 and parameters: {'kernel': 'rbf', 'C': 12.681831098714891, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:05,451] Trial 25 finished with value: 0.8597222222222222 and parameters: {'kernel': 'rbf', 'C': 163.9903774807083, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:05,243] Trial 23 finished with value: 0.8722222222222222 and parameters: {'kernel': 'rbf', 'C': 21.887333318066418, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:05,335] Trial 24 finished with value: 0.86875 and parameters: {'kernel': 'rbf', 'C': 12.681831098714891, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:05,451] Trial 25 finished with value: 0.8597222222222222 and parameters: {'kernel': 'rbf', 'C': 163.9903774807083, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:05,557] Trial 26 finished with value: 0.8645833333333334 and parameters: {'kernel': 'rbf', 'C': 7.1894430172165436, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:05,681] Trial 27 finished with value: 0.8506944444444445 and parameters: {'kernel': 'rbf', 'C': 1.8249731196702186, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# [I 2025-11-22 01:36:05,557] Trial 26 finished with value: 0.8645833333333334 and parameters: {'kernel': 'rbf', 'C': 7.1894430172165436, 'gamma': 'scale'}. Best is trial 15 with value: 0.8722222222222222.
# ...
# [I 2025-11-22 01:37:06,515] Trial 58 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.9120121001795745}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:06,756] Trial 59 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 1.666784006530815}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:06,756] Trial 59 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 1.666784006530815}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:07,212] Trial 60 finished with value: 0.9493055555555555 and parameters: {'kernel': 'rbf', 'C': 25.318631538650077, 'gamma': 'auto'}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:07,212] Trial 60 finished with value: 0.9493055555555555 and parameters: {'kernel': 'rbf', 'C': 25.318631538650077, 'gamma': 'auto'}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:07,452] Trial 61 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 170.17780125998962}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:07,452] Trial 61 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 170.17780125998962}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:07,687] Trial 62 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 692.2578468771178}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:07,687] Trial 62 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 692.2578468771178}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:07,942] Trial 63 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 628.5112721266648}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:07,942] Trial 63 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 628.5112721266648}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:08,166] Trial 64 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.3664666882398767}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:08,368] Trial 65 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 17.0048799110835}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:08,166] Trial 64 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.3664666882398767}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:08,368] Trial 65 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 17.0048799110835}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:08,825] Trial 66 finished with value: 0.7715277777777777 and parameters: {'kernel': 'poly', 'C': 997.7859133315425, 'degree': 4, 'gamma': 'scale'}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:09,040] Trial 67 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 229.99161098353875}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:08,825] Trial 66 finished with value: 0.7715277777777777 and parameters: {'kernel': 'poly', 'C': 997.7859133315425, 'degree': 4, 'gamma': 'scale'}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:09,040] Trial 67 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 229.99161098353875}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:09,255] Trial 68 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 2.598844088086442}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:09,255] Trial 68 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 2.598844088086442}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:09,478] Trial 69 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 10.938083258795166}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:09,680] Trial 70 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 1.244867786602719}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:09,478] Trial 69 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 10.938083258795166}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:09,680] Trial 70 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 1.244867786602719}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:09,883] Trial 71 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 3.409588418112702}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:10,086] Trial 72 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 6.116572176357362}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:09,883] Trial 71 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 3.409588418112702}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:10,086] Trial 72 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 6.116572176357362}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:10,289] Trial 73 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 8.609573721753028}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:10,289] Trial 73 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 8.609573721753028}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:10,502] Trial 74 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 3.6876388443089656}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:10,502] Trial 74 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 3.6876388443089656}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:10,883] Trial 75 finished with value: 0.9493055555555555 and parameters: {'kernel': 'rbf', 'C': 2.143287247552888, 'gamma': 'auto'}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:10,883] Trial 75 finished with value: 0.9493055555555555 and parameters: {'kernel': 'rbf', 'C': 2.143287247552888, 'gamma': 'auto'}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:11,097] Trial 76 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.6714445175789598}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:11,097] Trial 76 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.6714445175789598}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:11,480] Trial 77 finished with value: 0.8590277777777778 and parameters: {'kernel': 'poly', 'C': 86.65717978925272, 'degree': 3, 'gamma': 'scale'}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:11,480] Trial 77 finished with value: 0.8590277777777778 and parameters: {'kernel': 'poly', 'C': 86.65717978925272, 'degree': 3, 'gamma': 'scale'}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:11,716] Trial 78 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 5.0246034965163}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:11,716] Trial 78 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 5.0246034965163}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:11,929] Trial 79 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 358.012149560842}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:12,134] Trial 80 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 27.048989363229865}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:11,929] Trial 79 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 358.012149560842}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:12,134] Trial 80 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 27.048989363229865}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:12,347] Trial 81 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 17.780413886527512}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:12,347] Trial 81 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 17.780413886527512}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:12,560] Trial 82 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.10177153384164414}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:12,560] Trial 82 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.10177153384164414}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:12,793] Trial 83 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.4526793135379636}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:12,793] Trial 83 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.4526793135379636}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:13,028] Trial 84 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.16726354844598118}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:13,028] Trial 84 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.16726354844598118}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:13,243] Trial 85 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 1.5258862626954863}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:13,445] Trial 86 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.24318530639134434}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:13,243] Trial 85 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 1.5258862626954863}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:13,445] Trial 86 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.24318530639134434}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:13,837] Trial 87 finished with value: 0.9472222222222223 and parameters: {'kernel': 'rbf', 'C': 0.8565002815630752, 'gamma': 'auto'}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:13,837] Trial 87 finished with value: 0.9472222222222223 and parameters: {'kernel': 'rbf', 'C': 0.8565002815630752, 'gamma': 'auto'}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:14,052] Trial 88 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 2.2473675904251507}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:14,052] Trial 88 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 2.2473675904251507}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:14,511] Trial 89 finished with value: 0.5104166666666666 and parameters: {'kernel': 'poly', 'C': 3.325314047889884, 'degree': 5, 'gamma': 'auto'}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:14,511] Trial 89 finished with value: 0.5104166666666666 and parameters: {'kernel': 'poly', 'C': 3.325314047889884, 'degree': 5, 'gamma': 'auto'}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:14,725] Trial 90 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 1.2118344415951938}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:14,725] Trial 90 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 1.2118344415951938}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:14,938] Trial 91 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 7.948824107664881}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:14,938] Trial 91 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 7.948824107664881}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:15,151] Trial 92 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.6302226956600162}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:15,364] Trial 93 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 1.0480434310874986}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:15,151] Trial 92 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.6302226956600162}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:15,364] Trial 93 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 1.0480434310874986}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:15,567] Trial 94 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 40.534760454259846}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:15,768] Trial 95 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.38445593555322816}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:15,567] Trial 94 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 40.534760454259846}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:15,768] Trial 95 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 0.38445593555322816}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:15,982] Trial 96 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 1.708866111695337}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:15,982] Trial 96 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 1.708866111695337}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:16,196] Trial 97 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 11.587333770218953}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:16,408] Trial 98 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 4.543362781121962}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:16,196] Trial 97 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 11.587333770218953}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:16,408] Trial 98 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 4.543362781121962}. Best is trial 0 with value: 0.9499999999999998.
# [I 2025-11-22 01:37:16,655] Trial 99 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 14.557583909332854}. Best is trial 0 with value: 0.9499999999999998.
# ✓ SIFT_param2: CV=0.9500 | Test=0.9722
# [I 2025-11-22 01:37:16,655] Trial 99 finished with value: 0.9499999999999998 and parameters: {'kernel': 'linear', 'C': 14.557583909332854}. Best is trial 0 with value: 0.9499999999999998.
# ✓ SIFT_param2: CV=0.9500 | Test=0.9722

# %% [markdown]
# ## Classification Reports - All Models

# %%
for feat_name, result in optuna_results.items():
    model = result['model']
    
    if feat_name.startswith("LBP"):
        param_name = feat_name.replace("LBP_", "")
        X_test_feat = lbp_scaled[param_name]['test']
    else:
        param_name = feat_name.replace("SIFT_", "")
        X_test_feat = sift_scaled[param_name]['test']
    
    y_pred = model.predict(X_test_feat)
    
    print(f"Feature Set: {feat_name}")
    print(f"Feature Params: {result['feature_params']}")
    print(f"Best Model Params: {result['best_params']}")
    print(f"CV Accuracy: {result['cv_accuracy']:.4f} | Test Accuracy: {result['test_accuracy']:.4f}")
    print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# Feature Set: LBP_param1
# Feature Params: {'radius': 1, 'n_points': 8, 'method': 'default'}
# Best Model Params: {'kernel': 'rbf', 'C': 54.56725485601472, 'gamma': 'scale'}
# CV Accuracy: 0.9062 | Test Accuracy: 0.9111
#                  precision    recall  f1-score   support
#
#         crazing       0.89      0.98      0.94        60
#       inclusion       0.93      0.65      0.76        60
#         patches       0.98      0.88      0.93        60
#  pitted_surface       0.98      0.98      0.98        60
# rolled-in_scale       1.00      1.00      1.00        60
#       scratches       0.74      0.97      0.84        60
#
#        accuracy                           0.91       360
#       macro avg       0.92      0.91      0.91       360
#    weighted avg       0.92      0.91      0.91       360
#
# Feature Set: LBP_param2
# Feature Params: {'radius': 1, 'n_points': 8, 'method': 'uniform'}
# Best Model Params: {'kernel': 'rbf', 'C': 24.196253610127705, 'gamma': 'auto'}
# CV Accuracy: 0.8729 | Test Accuracy: 0.9139
#                  precision    recall  f1-score   support
#
#         crazing       0.85      0.97      0.91        60
#       inclusion       0.87      0.87      0.87        60
#         patches       0.94      0.83      0.88        60
#  pitted_surface       1.00      0.88      0.94        60
# rolled-in_scale       1.00      0.98      0.99        60
#       scratches       0.85      0.95      0.90        60
#
#        accuracy                           0.91       360
#       macro avg       0.92      0.91      0.91       360
#    weighted avg       0.92      0.91      0.91       360
#
# Feature Set: SIFT_param1
# Feature Params: {'vocab_size': 100}
# Best Model Params: {'kernel': 'rbf', 'C': 1.8552093692475922, 'gamma': 'auto'}
# CV Accuracy: 0.9576 | Test Accuracy: 0.9750
#                  precision    recall  f1-score   support
#
#         crazing       0.98      1.00      0.99        60
#       inclusion       0.94      0.98      0.96        60
#         patches       0.97      0.98      0.98        60
#  pitted_surface       1.00      0.95      0.97        60
# rolled-in_scale       0.98      0.97      0.97        60
#       scratches       0.98      0.97      0.97        60
#
#        accuracy                           0.97       360
#       macro avg       0.98      0.98      0.98       360
#    weighted avg       0.98      0.97      0.98       360
#
# Feature Set: SIFT_param2
# Feature Params: {'vocab_size': 200}
# Best Model Params: {'kernel': 'linear', 'C': 24.81040974867808}
# CV Accuracy: 0.9500 | Test Accuracy: 0.9722
#                  precision    recall  f1-score   support
#
#         crazing       0.98      1.00      0.99        60
#       inclusion       1.00      0.88      0.94        60
#         patches       0.97      1.00      0.98        60
#  pitted_surface       0.97      0.97      0.97        60
# rolled-in_scale       0.97      0.98      0.98        60
#       scratches       0.95      1.00      0.98        60
#
#        accuracy                           0.97       360
#       macro avg       0.97      0.97      0.97       360
#    weighted avg       0.97      0.97      0.97       360
